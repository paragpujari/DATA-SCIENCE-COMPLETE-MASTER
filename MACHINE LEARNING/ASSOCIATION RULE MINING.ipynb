# %%
# import all the necessary libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# load the dataset
data = pd.read_csv('D:\\Datasets\\store_data.csv')
print(data)
# Out:
#               shrimp            almonds      avocado    vegetables mix  \
# 0            burgers          meatballs         eggs               NaN
# 1            chutney                NaN          NaN               NaN
# 2             turkey            avocado          NaN               NaN
# 3      mineral water               milk   energy bar  whole wheat rice
# 4     low fat yogurt                NaN          NaN               NaN
# ...              ...                ...          ...               ...
# 7495          butter         light mayo  fresh bread               NaN
# 7496         burgers  frozen vegetables         eggs      french fries
# 7497         chicken                NaN          NaN               NaN
# 7498        escalope          green tea          NaN               NaN
# 7499            eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#      green grapes whole weat flour yams cottage cheese energy drink  \
# ...

# %%
# display the first five rows of the dataset
print(data.head())
# Out:
#            shrimp    almonds     avocado    vegetables mix green grapes  \
# 0         burgers  meatballs        eggs               NaN          NaN
# 1         chutney        NaN         NaN               NaN          NaN
# 2          turkey    avocado         NaN               NaN          NaN
# 3   mineral water       milk  energy bar  whole wheat rice    green tea
# 4  low fat yogurt        NaN         NaN               NaN          NaN
#
#   whole weat flour yams cottage cheese energy drink tomato juice  \
# 0              NaN  NaN            NaN          NaN          NaN
# 1              NaN  NaN            NaN          NaN          NaN
# 2              NaN  NaN            NaN          NaN          NaN
# 3              NaN  NaN            NaN          NaN          NaN
# 4              NaN  NaN            NaN          NaN          NaN
#
#   low fat yogurt green tea honey salad mineral water salmon antioxydant juice  \
# ...

# %%
# display the last five rows of the dataset
print(data.tail())
# Out:
#         shrimp            almonds      avocado  vegetables mix green grapes  \
# 7495    butter         light mayo  fresh bread             NaN          NaN
# 7496   burgers  frozen vegetables         eggs    french fries    magazines
# 7497   chicken                NaN          NaN             NaN          NaN
# 7498  escalope          green tea          NaN             NaN          NaN
# 7499      eggs    frozen smoothie  yogurt cake  low fat yogurt          NaN
#
#      whole weat flour yams cottage cheese energy drink tomato juice  \
# 7495              NaN  NaN            NaN          NaN          NaN
# 7496        green tea  NaN            NaN          NaN          NaN
# 7497              NaN  NaN            NaN          NaN          NaN
# 7498              NaN  NaN            NaN          NaN          NaN
# 7499              NaN  NaN            NaN          NaN          NaN
#
#      low fat yogurt green tea honey salad mineral water salmon  \
# ...

# %%
# shape of the dataset
print(data.shape)
# Out:
# (7500, 20)

# %%
# To check if there are any NULL Values in the dataset
data.isnull().sum()
# Out:
# shrimp                  0
# almonds              1754
# avocado              3112
# vegetables mix       4156
# green grapes         4972
# whole weat flour     5637
# yams                 6132
# cottage cheese       6520
# energy drink         6847
# tomato juice         7106
# low fat yogurt       7245
# green tea            7347
# honey                7414
# salad                7454
# mineral water        7476
# salmon               7493
# antioxydant juice    7497
# frozen smoothie      7497
# spinach              7498
# olive oil            7500
# dtype: int64

# %% [markdown]
# # So from the above observation , it is clear that there are many NOT-NULL Values in the dataset

# %%
# convert the dataframe into the list of lists
records = []
for i in range(0,7501):
    records.append(str(datasetvalues[i,j]) for j in range(0,20))

# %%
print(records)
# Out:
# [<generator object <genexpr> at 0x000002179AACD510>, <generator object <genexpr> at 0x000002179AACD5F0>, <generator object <genexpr> at 0x000002179AACD580>, <generator object <genexpr> at 0x000002179AACD660>, <generator object <genexpr> at 0x000002179AACD6D0>, <generator object <genexpr> at 0x000002179AACD740>, <generator object <genexpr> at 0x000002179AACD7B0>, <generator object <genexpr> at 0x000002179AACD820>, <generator object <genexpr> at 0x000002179AACD890>, <generator object <genexpr> at 0x000002179AACD900>, <generator object <genexpr> at 0x000002179AACD970>, <generator object <genexpr> at 0x000002179AACD9E0>, <generator object <genexpr> at 0x000002179AACDA50>, <generator object <genexpr> at 0x000002179AACDAC0>, <generator object <genexpr> at 0x000002179AACDB30>, <generator object <genexpr> at 0x000002179AACDBA0>, <generator object <genexpr> at 0x000002179AACDC10>, <generator object <genexpr> at 0x000002179AACDC80>, <generator object <genexpr> at 0x000002179AACDCF0>, <generato
# ...

# %%
# length of the record
print(len(records))
# Out:
# 7501

# %%
# first record
print(records[1])
# Out:
# <generator object <genexpr> at 0x000002179AACD5F0>

# %%
# Building the apriori model
from apyori import apriori
association_rules = apriori(records , min_support = 0.0045, min_confidence = 0.2, min_lift = 3, min_len = 2)
