# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas_datareader as pdr
key=""

# %%
df = pd.read_csv('/content/AAPL.csv')

# %%
# display the first five rows of the dataframe
df.head()
# Out:
#    Unnamed: 0 symbol                       date    close     high     low  \
# 0           0   AAPL  2015-05-27 00:00:00+00:00  132.045  132.260  130.05
# 1           1   AAPL  2015-05-28 00:00:00+00:00  131.780  131.950  131.10
# 2           2   AAPL  2015-05-29 00:00:00+00:00  130.280  131.450  129.90
# 3           3   AAPL  2015-06-01 00:00:00+00:00  130.535  131.390  130.05
# 4           4   AAPL  2015-06-02 00:00:00+00:00  129.960  130.655  129.32
#
#      open    volume    adjClose     adjHigh      adjLow     adjOpen  \
# 0  130.34  45833246  121.682558  121.880685  119.844118  120.111360
# 1  131.86  30733309  121.438354  121.595013  120.811718  121.512076
# 2  131.23  50884452  120.056069  121.134251  119.705890  120.931516
# 3  131.20  32112797  120.291057  121.078960  119.844118  120.903870
# 4  129.86  33667627  119.761181  120.401640  119.171406  119.669029
#
#    adjVolume  divCash  splitFactor
# 0   45833246      0.0          1.0
# 1   30733309      0.0          1.0
# ...

# %%
# display the last five rows of the dataframe
df.tail()
# Out:
#       Unnamed: 0 symbol                       date   close    high       low  \
# 1253        1253   AAPL  2020-05-18 00:00:00+00:00  314.96  316.50  310.3241
# 1254        1254   AAPL  2020-05-19 00:00:00+00:00  313.14  318.52  313.0100
# 1255        1255   AAPL  2020-05-20 00:00:00+00:00  319.23  319.52  316.2000
# 1256        1256   AAPL  2020-05-21 00:00:00+00:00  316.85  320.89  315.8700
# 1257        1257   AAPL  2020-05-22 00:00:00+00:00  318.89  319.23  315.3500
#
#         open    volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  \
# 1253  313.17  33843125    314.96   316.50  310.3241   313.17   33843125
# 1254  315.03  25432385    313.14   318.52  313.0100   315.03   25432385
# 1255  316.68  27876215    319.23   319.52  316.2000   316.68   27876215
# 1256  318.66  25672211    316.85   320.89  315.8700   318.66   25672211
# 1257  315.77  20450754    318.89   319.23  315.3500   315.77   20450754
#
#       divCash  splitFactor
# 1253      0.0          1.0
# ...

# %%
df.shape
# Out:
# (1258, 15)

# %%
# set the index position of the dataframe
df1 = df.reset_index()['close']
print(df1.head())
# Out:
# 0    132.045
# 1    131.780
# 2    130.280
# 3    130.535
# 4    129.960
# Name: close, dtype: float64

# %%
# To get the descriptive information about the columns in the dataset
print(df1.info())
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1258 entries, 0 to 1257
# Series name: close
# Non-Null Count  Dtype
# --------------  -----
# 1258 non-null   float64
# dtypes: float64(1)
# memory usage: 10.0 KB
# None

# %%
# To get the statistical information about the columns in the dataset
print(df1.describe())
# Out:
# count    1258.000000
# mean      167.723998
# std        56.850796
# min        90.340000
# 25%       116.327500
# 50%       160.485000
# 75%       199.785000
# max       327.200000
# Name: close, dtype: float64

# %%
# To check if there are any NULL Values in the dataset
print(df1.isnull().sum())
# Out:
# 0

# %%
# Observation:

##From the above observation, it is clear that there are no NULL Values for the close column in the dataset

# %%
# Plotting the graph of the dataset

plt.plot(df1)

# %%
# import the library for Minmaxscaler
from sklearn.preprocessing import MinMaxScaler

# create the object for MinMaxScaler
scaler = MinMaxScaler(feature_range = (0,1))

# train and transform the data
df1 = scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
print(df1)
# Out:
# [[0.17607447]
#  [0.17495567]
#  [0.16862282]
#  ...
#  [0.96635143]
#  [0.9563033 ]
#  [0.96491598]]

# %%
# splitting the dataset into training and testing data

training_size = int(len(df1) * 0.65)
test_size = len(df1) - training_size
train_data, test_data = df1[0:training_size,:],df1[training_size:len(df1),:1]

# %%
training_size, test_size
# Out:
# (817, 441)

# %%
train_data
# Out:
# array([[0.17607447],
#        [0.17495567],
#        [0.16862282],
#        [0.1696994 ],
#        [0.16727181],
#        [0.16794731],
#        [0.16473866],
#        [0.16174111],
#        [0.1581525 ],
#        [0.15654817],
#        [0.16271215],
#        [0.1614878 ],
#        [0.1554927 ],
#        [0.15443722],
#        [0.15730811],
#        [0.15604154],
#        [0.15849025],
#        [0.15308621],
#        [0.15735033],
#        [0.15490163],
#        [0.15946129],
#        [0.15688592],
#        [0.1537195 ],
#        [0.14434687],
#        [0.14812547],
#        [0.15308621],
#        [0.15241071],
#        [0.15055307],
#        [0.14924428],
#        [0.13607194],
#        [0.12551718],
#        [0.13906949],
#        [0.14911762],
#        [0.14890653],
#        [0.15401503],
#        [0.16115005],
#        [0.16583636],
#        [0.17618002],
#        [0.17060711],
#        [0.14725998],
#        [0.14700667],
#        [0.14422021],
#        [0.13691632],
# ...

# %%
test_data
# Out:
# array([[0.52651355],
#        [0.52837119],
#        [0.53119986],
#        [0.53871485],
#        [0.5461454 ],
#        [0.55999324],
#        [0.56864815],
#        [0.57962509],
#        [0.58270708],
#        [0.57641645],
#        [0.56049987],
#        [0.55290045],
#        [0.54036139],
#        [0.5636663 ],
#        [0.55192941],
#        [0.57447437],
#        [0.56362408],
#        [0.53846154],
#        [0.53998142],
#        [0.54053027],
#        [0.54753863],
#        [0.53753272],
#        [0.55074728],
#        [0.55665794],
#        [0.54918517],
#        [0.56831039],
#        [0.5716457 ],
#        [0.57806299],
#        [0.58659124],
#        [0.59837035],
#        [0.58114498],
#        [0.56552394],
#        [0.56332855],
#        [0.57641645],
#        [0.53204425],
#        [0.52398041],
#        [0.55632019],
#        [0.53626615],
#        [0.55648907],
#        [0.55243604],
#        [0.5306088 ],
#        [0.54449886],
#        [0.55015621],
# ...

# %%
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (716, 100)
# (716,)
# (None, None)

# %%
print(X_test.shape), print(ytest.shape)
# Out:
# (340, 100)
# (340,)
# (None, None)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
### Create the Stacked LSTM model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
# Create the LSTM Model

model = Sequential()

# add the first lstm layer
model.add(LSTM(50, return_sequences= True, input_shape = (100,1)))
# add the second LSTM Layer
model.add(LSTM(50, return_sequences = True))
# add the third LSTM Layer
model.add(LSTM(50))
# add the dense later
model.add(Dense(1))
# compile the model using mean squared error and adam optimizer
model.compile(loss = 'mean_squared_error', optimizer = 'adam')

# %%
# provide the summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 100, 50)           10400
#
#  lstm_1 (LSTM)               (None, 100, 50)           20200
#
#  lstm_2 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 1)                 51
#
# ...
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train the model
model.fit(X_train, y_train, validation_data = (X_test, ytest), epochs = 100, batch_size = 64, verbose = 1)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 10s 320ms/step - loss: 0.0194 - val_loss: 0.0603
# Epoch 2/100
# 12/12 [==============================] - 3s 217ms/step - loss: 0.0043 - val_loss: 0.0050
# Epoch 3/100
# 12/12 [==============================] - 3s 244ms/step - loss: 0.0015 - val_loss: 0.0043
# Epoch 4/100
# 12/12 [==============================] - 4s 290ms/step - loss: 9.0740e-04 - val_loss: 0.0050
# Epoch 5/100
# 12/12 [==============================] - 3s 214ms/step - loss: 7.2732e-04 - val_loss: 0.0067
# Epoch 6/100
# 12/12 [==============================] - 3s 218ms/step - loss: 7.1256e-04 - val_loss: 0.0050
# Epoch 7/100
# 12/12 [==============================] - 3s 215ms/step - loss: 6.9629e-04 - val_loss: 0.0041
# Epoch 8/100
# 12/12 [==============================] - 4s 312ms/step - loss: 6.7309e-04 - val_loss: 0.0036
# Epoch 9/100
# 12/12 [==============================] - 3s 223ms/step - loss: 6.5976e-04 - val_loss: 0.0039
# Epoch 10/100
# ...

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.12.0'

# %%
# let's do the prediction of the model
train_predict = model.predict(X_train)

test_predict = model.predict(X_test)
# Out:
# ...
# 11/11 [==============================] - 0s 42ms/step

# %%
# Transform back into original form
train_predict = scaler.inverse_transform(train_predict)

test_predict = scaler.inverse_transform(test_predict)

# %%
### Calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error

mean_squared_error(y_train, train_predict)
# Out:
# 20061.89456020579

# %%
### Test Data RMSE
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 238.6225328885454

# %%
### Plotting
# shift train predictions for plotting
look_back=100
trainPredictPlot = numpy.empty_like(df1)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df1)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df1)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df1))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
len(test_data)
# Out:
# 441

# %%
x_input = test_data[341:].reshape(-1,1)
x_input.shape
# Out:
# (100, 1)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
temp_input
# Out:
# [0.8583551465000423]

# %%
# demonstrate prediction for next 10 days
from numpy import array

lst_output=[]
n_steps=100
i=0
while(i<30):

    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1


print(lst_output)
# Out:
# [0.9660399]
# 2
# [0.9660399]
# 3
# [0.9660399]
# 4
# [0.9660399]
# 5
# [0.9660399]
# 6
# [0.9660399]
# 7
# [0.9660399]
# 8
# [0.9660399]
# 9
# [0.9660399]
# 10
# [0.9660399]
# 11
# [0.9660399]
# 12
# [0.9660399]
# 13
# [0.9660399]
# 14
# [0.9660399]
# 15
# [0.9660399]
# 16
# [0.9660399]
# 17
# [0.9660399]
# 18
# [0.9660399]
# 19
# [0.9660399]
# 20
# [0.9660399]
# 21
# [0.9660399]
# 22
# [0.9660399]
# 23
# [0.9660399]
# 24
# [0.9660399]
# 25
# [0.9660399]
# 26
# [0.9660399]
# 27
# [0.9660399]
# 28
# [0.9660399]
# 29
# [0.9660399]
# 30
# [0.9660399]
# 31
# ...

# %%
day_new=np.arange(1,101)
day_pred=np.arange(101,131)

# %%
len(df1)
# Out:
# 1258

# %%
plt.plot(day_new,scaler.inverse_transform(df1[1158:]))
plt.plot(day_pred,scaler.inverse_transform(lst_output))

# %%
df3=df1.tolist()
df3.extend(lst_output)
plt.plot(df3[1200:])

# %%
df3=scaler.inverse_transform(df3).tolist()
plt.plot(df3)
